# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matplotlib

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.xlabel('x range')
plt.show()

# %%
_ = plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
#plt.axis([0, 6, 0, 20])
#plt.xlim(0, 10)
plt.ylim(0, 100)
plt.show()

# %%
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
t * 2
# Out:
# array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. , 4.4, 4.8,
#        5.2, 5.6, 6. , 6.4, 6.8, 7.2, 7.6, 8. , 8.4, 8.8, 9.2, 9.6])

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
#plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.plot(t, t, 'r--')
plt.show()
plt.plot(t, t**2, 'bs')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9,6))

plt.subplot(231)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)
#plt.plot(names, values, "ro")

plt.subplot(133)
plt.plot(names, values)

plt.subplot(231)
plt.bar(names, values)

plt.subplot(232)
plt.scatter(names, values)
#plt.plot(names, values, "ro")

plt.subplot(233)
plt.plot(names, values)

#plt.suptitle('Categorical Plotting')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   app.launch_new_instance()

# %%
x[:10]
# Out:
# array([100.66469854,  98.27446704,  76.07136825, 123.88521065,
#        100.29685951, 141.45912216, 117.24498441, 100.16989556,
#        100.63335037,  83.63104072])

# %%
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, 0.025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Pandas

# %%
data = pd.read_csv("sample_covid_data.csv", index_col=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data
# Out:
#         cord_uid  sha source_x  \
# 94305   4mky2qwy  NaN  Medline
# 586896  odxm2fgt  NaN      WHO
# 107517  8dz5jyn9  NaN  Medline
# 144178  5a0ac7gx  NaN  Medline
# 76026   f84n2ef0  NaN  Medline
# ...          ...  ...      ...
# 229199  9mcgpzp5  NaN  Medline
# 122628  0emibwp3  NaN  Medline
# 371551  grhtho9o  NaN      WHO
# 394971  67gaybtp  NaN      WHO
# 211640  lugrk7ig  NaN      WHO
#
#                                                     title  \
# 94305                              Finding a new balance.
# 586896  COVID19-Tracker: una aplicación Shiny para ana...
# 107517                             When Duty House Calls.
# 144178  Editorial: Publishing in the Time of Pandemic:...
# 76026   Advanced Stages and Increased Need for Adjuvan...
# ...                                                   ...
# 229199  Diagnosis of human metapneumovirus infection i...
# 122628               Reducing transmission of SARS-CoV-2.
# ...

# %%
data.describe(include='all')
# Out:
#         cord_uid                                       sha source_x  title  \
# count      65000                                     21989    65000  64974
# unique     64406                                     21989       38  63546
# top     kgpo6psq  87825f766a6cbd221718d3ee6557088ce18c3ebe      WHO  Reply
# freq          15                                         1    28962     19
# mean         NaN                                       NaN      NaN    NaN
# std          NaN                                       NaN      NaN    NaN
# min          NaN                                       NaN      NaN    NaN
# 25%          NaN                                       NaN      NaN    NaN
# 50%          NaN                                       NaN      NaN    NaN
# 75%          NaN                                       NaN      NaN    NaN
# max          NaN                                       NaN      NaN    NaN
#
#                         doi       pmcid pubmed_id license  \
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls ./drive/MyDrive/submission123.csv

# %%
data_example = pd.read_csv("./drive/MyDrive/submission123.csv")

# %%
data_example.to_csv("./drive/MyDrive/example.csv")
# Out:
#    index  main_category
# 0      0              5
# 1      1             16
# 2      2             20
# 3      3              7
# 4      4             12

# %%
data.journal.value_counts()[:10]
# Out:
# PLoS One                           658
# bioRxiv                            520
# BMJ                                490
# Int J Environ Res Public Health    373
# Sci Rep                            371
# Cureus                             258
# Nature                             245
# Lancet                             241
# Viruses                            218
# BMJ Open                           194
# Name: journal, dtype: int64

# %%
# plot top 10 only
data.journal.value_counts()[0:10].plot(kind='bar')
plt.grid()
plt.show()

# %%
data.source_x.value_counts().plot(kind='bar')
plt.show()

# %%
data.publish_time
# Out:
# 94305     2020-05-16
# 586896          2020
# 107517    2020-09-14
# 144178    2020-06-22
# 76026     2021-05-01
#              ...
# 229199          2007
# 122628    2020-05-27
# 371551          2020
# 394971          2020
# 211640          2022
# Name: publish_time, Length: 65000, dtype: object

# %%
data.publish_time = data.publish_time.astype('datetime64[ns]')

# %%
data.publish_time
# Out:
# 94305    2020-05-16
# 586896   2020-01-01
# 107517   2020-09-14
# 144178   2020-06-22
# 76026    2021-05-01
#             ...
# 229199   2007-01-01
# 122628   2020-05-27
# 371551   2020-01-01
# 394971   2020-01-01
# 211640   2022-01-01
# Name: publish_time, Length: 65000, dtype: datetime64[ns]

# %%
dates_count = data.publish_time.dt.year.value_counts()

# %%
dates_count
# Out:
# 2021.0    30649
# 2020.0    27033
# 2019.0      654
# 2016.0      617
# 2018.0      594
#           ...
# 1972.0        1
# 1974.0        1
# 1951.0        1
# 1857.0        1
# 1958.0        1
# Name: publish_time, Length: 63, dtype: int64

# %%
dates_count.iloc[0:20].plot.bar()

# %%
counts = {}
filter_year = 2000

counts["x"] = [int(i) for i, j in dates_count.items() if i > filter_year]

counts["y"] = [1 for _ in counts["x"]]

counts["size"] = [int(j) for i, j in dates_count.items() if i > filter_year]
counts['color'] = np.random.randint(0, 50, len(counts["x"]))

plt.scatter('x', 'y', c='color', s='size', data=counts, alpha=.2)
plt.title("Number of articals per year")
plt.plot()
# Out:
# []

# %%
# !pip install wordcloud
# !pip install plotly

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import time
import warnings 
warnings.filterwarnings('ignore')

# %%
def word_bar_graph_function(df, column, title, nvals=50):
    # adapted from https://www.kaggle.com/benhamner/most-common-forum-topic-words

    topic_words = [z.lower() for y in [x.split() for x in df[column] if isinstance(x, str)] for z in y]
    
    word_count_dict = dict(Counter(topic_words))
    popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
    popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
    plt.barh(range(nvals), [word_count_dict[w] for w in reversed(popular_words_nonstop[0:nvals])])
    plt.yticks([x + 0.5 for x in range(nvals)], reversed(popular_words_nonstop[0:nvals]))
    plt.title(title)
    plt.show()

# %%
# show most frequent words in titles
plt.figure(figsize=(10,10))
word_bar_graph_function(data,column='title', 
                        title='Most common words in the TITLES of the papers in the CORD-19 dataset',
                        nvals=20)

# %%
def count_ngrams(dataframe, column, begin_ngram, end_ngram):
    # adapted from https://stackoverflow.com/questions/36572221/how-to-find-ngram-frequency-of-a-column-in-a-pandas-dataframe
    word_vectorizer = CountVectorizer(ngram_range=(begin_ngram,end_ngram), analyzer='word')
    sparse_matrix = word_vectorizer.fit_transform(dataframe[column].dropna())
    frequencies = sum(sparse_matrix).toarray()[0]
    most_common = pd.DataFrame(frequencies, 
                               index=word_vectorizer.get_feature_names(), 
                               columns=['frequency']).sort_values('frequency',ascending=False)
    most_common['ngram'] = most_common.index
    most_common.reset_index()
    return most_common

# %%
# evaluate 3-grams (takes some time)
t1 = time.time()
three_gram = count_ngrams(data,'title',1,1)
t2 = time.time()
print('Elapsed time:', t2-t1)
# Out:
# Elapsed time: 37.1937472820282

# %%
three_gram[0:20]
# Out:
#              frequency        ngram
# of               43786           of
# the              34452          the
# and              32686          and
# in               32266           in
# covid            31269        covid
# 19               30611           19
# for              12746          for
# to               10541           to
# with              9900         with
# pandemic          8581     pandemic
# on                7730           on
# during            7204       during
# sars              6685         sars
# cov               6306          cov
# patients          6114     patients
# from              4574         from
# study             4292        study
# health            4070       health
# an                3968           an
# coronavirus       3901  coronavirus

# %%
def word_cloud_function(df, column, number_of_words):
    # adapted from https://www.kaggle.com/benhamner/most-common-forum-topic-words
    topic_words = [ z.lower() for y in
                       [ x.split() for x in df[column] if isinstance(x, str)]
                       for z in y]
    word_count_dict = dict(Counter(topic_words))
    popular_words = sorted(word_count_dict, key = word_count_dict.get, reverse = True)
    popular_words_nonstop = [w for w in popular_words if w not in stopwords.words("english")]
    word_string=str(popular_words_nonstop)
    wordcloud = WordCloud(stopwords=STOPWORDS,
                          background_color='white',
                          max_words=number_of_words,
                          width=1000,height=1000,
                         ).generate(word_string)
    plt.clf()
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
plt.figure(figsize=(10,10))
word_cloud_function(data,column='title',number_of_words=500)
